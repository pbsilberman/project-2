# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import pandas as pd

# %%
engine = create_engine("sqlite:///db/divvy.sqlite")

# %%
Base = automap_base()

# %%
Base.prepare(engine,reflect=True)

# %%
Base.classes.keys()
# Out:
# ['station', 'trip']

# %%
session = Session(engine)

# %%
query = "select * from station"

# %%
pd.read_sql_query(query,session.bind).head()
# Out:
#    id  station_id                    name   latitude  longitude  dpcapacity  \
# 0   1           2     Buckingham Fountain  41.876393 -87.620328          27
# 1   2           3          Shedd Aquarium  41.867226 -87.615355          55
# 2   3           4          Burnham Harbor  41.856268 -87.613348          23
# 3   4           5  State St & Harrison St  41.874053 -87.627716          23
# 4   5           6          Dusable Harbor  41.885041 -87.612794          39
#
#        online_date
# 0  6/10/2013 10:43
# 1  6/10/2013 10:44
# 2  6/10/2013 10:46
# 3  6/10/2013 10:46
# 4  6/10/2013 11:18

# %%
station=pd.read_sql_query(query,session.bind)

# %%
station.to_dict(orient="records")
# json data
# Out:
# [{'id': 1,
#   'station_id': 2,
#   'name': 'Buckingham Fountain',
#   'latitude': 41.876393,
#   'longitude': -87.620328,
#   'dpcapacity': 27,
#   'online_date': '6/10/2013 10:43'},
#  {'id': 2,
#   'station_id': 3,
#   'name': 'Shedd Aquarium',
#   'latitude': 41.86722596,
#   'longitude': -87.61535539,
#   'dpcapacity': 55,
#   'online_date': '6/10/2013 10:44'},
#  {'id': 3,
#   'station_id': 4,
#   'name': 'Burnham Harbor',
#   'latitude': 41.856268,
#   'longitude': -87.613348,
#   'dpcapacity': 23,
#   'online_date': '6/10/2013 10:46'},
#  {'id': 4,
#   'station_id': 5,
#   'name': 'State St & Harrison St',
#   'latitude': 41.874053,
#   'longitude': -87.627716,
#   'dpcapacity': 23,
#   'online_date': '6/10/2013 10:46'},
#  {'id': 5,
#   'station_id': 6,
#   'name': 'Dusable Harbor',
#   'latitude': 41.885040999999994,
#   'longitude': -87.612794,
#   'dpcapacity': 39,
#   'online_date': '6/10/2013 11:18'},
#  {'id': 6,
#   'station_id': 7,
# ...

# %%
query = "select * from trip"

# %%
pd.read_sql_query(query,session.bind).head()
# Out:
#    id   trip_id        start_time          end_time  tripduration  \
# 0   1  17536701  12/31/2017 23:58     1/1/2018 0:03           284
# 1   2  17536700  12/31/2017 23:54     1/1/2018 0:18          1402
# 2   3  17536699  12/31/2017 23:54     1/1/2018 0:18          1441
# 3   4  17536698  12/31/2017 23:48  12/31/2017 23:53           315
# 4   5  17536697  12/31/2017 23:42  12/31/2017 23:47           272
#
#    from_station_id  to_station_id    usertype gender  birthyear
# 0              159             69  Subscriber   Male     1988.0
# 1              145            145    Customer   None        NaN
# 2              145            145    Customer   None        NaN
# 3              340            143  Subscriber   Male     1963.0
# 4              240            245  Subscriber   Male     1977.0

# %%
trip=pd.read_sql_query(query,session.bind)

# %%
trip.to_dict(orient="records")
# Out:
# [{'id': 1,
#   'trip_id': 17536701,
#   'start_time': '12/31/2017 23:58',
#   'end_time': '1/1/2018 0:03',
#   'tripduration': 284,
#   'from_station_id': 159,
#   'to_station_id': 69,
#   'usertype': 'Subscriber',
#   'gender': 'Male',
#   'birthyear': 1988.0},
#  {'id': 2,
#   'trip_id': 17536700,
#   'start_time': '12/31/2017 23:54',
#   'end_time': '1/1/2018 0:18',
#   'tripduration': 1402,
#   'from_station_id': 145,
#   'to_station_id': 145,
#   'usertype': 'Customer',
#   'gender': None,
#   'birthyear': nan},
#  {'id': 3,
#   'trip_id': 17536699,
#   'start_time': '12/31/2017 23:54',
#   'end_time': '1/1/2018 0:18',
#   'tripduration': 1441,
#   'from_station_id': 145,
#   'to_station_id': 145,
#   'usertype': 'Customer',
#   'gender': None,
#   'birthyear': nan},
#  {'id': 4,
#   'trip_id': 17536698,
#   'start_time': '12/31/2017 23:48',
#   'end_time': '12/31/2017 23:53',
#   'tripduration': 315,
#   'from_station_id': 340,
#   'to_station_id': 143,
# ...
